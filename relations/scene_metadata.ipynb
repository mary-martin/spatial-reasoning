# %%
import json
import os
from scene_objects import Scene_Objects, Entity

data_dir = "/home/mary/Code/spatial-reasoning/custom_clevr/output/scenes/"
scene_file = "CLEVR_train_000000.json"
output_dir = "/home/mary/Code/spatial-reasoning/relations/"

# %%
with open(os.path.join(data_dir, scene_file)) as data:
    scene_data = json.load(data)

print(scene_data.keys())
directions = scene_data['directions']
relationships = scene_data['relationships']
objects = scene_data['objects']
print(directions)
print(relationships)
print(objects)
print(relationships['front'][0])
# Out:
# dict_keys(['obj_bbox', 'directions', 'obj_mask', 'objects', 'relationships', 'image_index', 'split', 'image_filename'])
# {'right': [0.6563112735748291, 0.7544902563095093, -0.0], 'left': [-0.6563112735748291, -0.7544902563095093, 0.0], 'behind': [-0.754490315914154, 0.6563112735748291, 0.0], 'below': [-0.0, -0.0, -1.0], 'front': [0.754490315914154, -0.6563112735748291, -0.0], 'above': [0.0, 0.0, 1.0]}
# {'right': [[2, 5], [0, 2, 3, 4, 5], [5], [0, 2, 4, 5], [0, 2, 5], []], 'front': [[1, 2, 3, 4, 5], [2, 3, 4], [3, 4], [4], [], [1, 2, 3, 4]], 'left': [[1, 3, 4], [], [0, 1, 3, 4], [1], [1, 3], [0, 1, 2, 3, 4]], 'behind': [[], [0, 5], [0, 1, 5], [0, 1, 2, 5], [0, 1, 2, 3, 5], [0]]}
# [{'location': [-1.3705521821975708, 2.0794010162353516, 0.699999988079071], 'pixel_coords': [265, 94, 13.42684268951416], 'size': 'large', 'color': 'blue', 'shape': 'cube', '3d_coords': [-1.3705521821975708, 2.0794010162353516, 0.699999988079071], 'rotation': 269.8517172617167, 'idx': 1, 'material': 'rubber'}, {'location': [-2.9289753437042236, -1.7488206624984741, 0.699999988079071], 'pixel_coords': [100, 113, 12.189724922180176], 'size': 'large', 'color': 'green', 'shape': 'cylinder', '3d_coords': [-2.9289753437042236, -1.7488206624984741, 0.699999988079071], 'rotation': 292.2219458666971, 'idx': 2, 'material': 'metal'}, {'location': [1.5515961647033691, 0.6776641607284546, 0.3499999940395355], 'pixel_coords': [315, 160, 10.793452262878418], 'size': 'small', 'color': 'cyan', 'shape': 'cube', '3d_coords': [1.5515961647033691, 0.6776641607284546, 0.3499999940395355], 'rotation': 25.545135239473026, 'idx': 3, 'material': 'rubber'}, {'location': [-0.25301405787467957, -2.3089325428009033, 0.699999988079071], 'pixel_coords': [141, 159, 10.066368103027344], 'size': 'large', 'color': 'brown', 'shape': 'cylinder', '3d_coords': [-0.25301405787467957, -2.3089325428009033, 0.699999988079071], 'rotation': 327.3489188814305, 'idx': 4, 'material': 'metal'}, {'location': [1.018894076347351, -1.93693208694458, 0.3499999940395355], 'pixel_coords': [198, 193, 9.592914581298828], 'size': 'small', 'color': 'gray', 'shape': 'cube', '3d_coords': [1.018894076347351, -1.93693208694458, 0.3499999940395355], 'rotation': 6.325183772442613, 'idx': 5, 'material': 'rubber'}, {'location': [0.43993687629699707, 2.9987525939941406, 0.699999988079071], 'pixel_coords': [344, 104, 12.763299942016602], 'size': 'large', 'color': 'brown', 'shape': 'sphere', '3d_coords': [0.43993687629699707, 2.9987525939941406, 0.699999988079071], 'rotation': 25.96049348342493, 'idx': 6, 'material': 'metal'}]
# [1, 2, 3, 4, 5]

# %%
scene_info = Scene_Objects(scene_data)
entities = scene_info.all_entities
# for entity in entities:
#     print(entity)
scene_info.obj_offsets.show_data_range()
# Out:
# {'distance': array([-1.55842316, -3.82822168,  0.        ]), 'direction': array([-1., -1.,  0.]), 'xyz_offsets': [1.5584231615066528, 3.8282216787338257, 0.0], 'theta_degrees': 18.290574586124084, 'theta_radians': 0.3192307486094644, 'cos_theta': 0.9494771179688208, 'sin_theta': 0.31383626695081285}
# {'distance': array([ 2.92214835, -1.40173686, -0.34999999]), 'direction': array([ 1., -1., -1.]), 'xyz_offsets': [-2.92214834690094, 1.401736855506897, 0.3499999940395355], 'theta_degrees': 9.627779735978518, 'theta_radians': 0.16803645604961548, 'cos_theta': 0.985915063711307, 'sin_theta': 0.16724678516231478}
# {'distance': array([ 1.11753812, -4.38833356,  0.        ]), 'direction': array([ 1., -1.,  0.]), 'xyz_offsets': [-1.1175381243228912, 4.388333559036255, 0.0], 'theta_degrees': 15.424942648462682, 'theta_radians': 0.26921603614696804, 'cos_theta': 0.9639797079828473, 'sin_theta': 0.2659757932543947}
# {'distance': array([ 2.38944626, -4.0163331 , -0.34999999]), 'direction': array([ 1., -1., -1.]), 'xyz_offsets': [-2.389446258544922, 4.016333103179932, 0.3499999940395355], 'theta_degrees': 13.445251484359572, 'theta_radians': 0.2346639071607294, 'cos_theta': 0.972592543264445, 'sin_theta': 0.2325161172615754}
# {'distance': array([1.81048906, 0.91935158, 0.        ]), 'direction': array([1., 1., 0.]), 'xyz_offsets': [-1.8104890584945679, -0.9193515777587891, 0.0], 'theta_degrees': 8.822803361020032, 'theta_radians': 0.1539869679058215, 'cos_theta': 0.9881674157772941, 'sin_theta': 0.15337913285719298}
# {'distance': array([1.55842316, 3.82822168, 0.        ]), 'direction': array([1., 1., 0.]), 'xyz_offsets': [-1.5584231615066528, -3.8282216787338257, 0.0], 'theta_degrees': 18.290574586124084, 'theta_radians': 0.3192307486094644, 'cos_theta': 0.9494771179688208, 'sin_theta': 0.31383626695081285}
# {'distance': array([ 4.48057151,  2.42648482, -0.34999999]), 'direction': array([ 1.,  1., -1.]), 'xyz_offsets': [-4.480571508407593, -2.4264848232269287, 0.3499999940395355], 'theta_degrees': 24.67323336441849, 'theta_radians': 0.43062915932202056, 'cos_theta': 0.9087032916376067, 'sin_theta': 0.41744260415891765}
# {'distance': array([ 2.67596129, -0.56011188,  0.        ]), 'direction': array([ 1., -1.,  0.]), 'xyz_offsets': [-2.675961285829544, 0.5601118803024292, 0.0], 'theta_degrees': 6.969893603887036, 'theta_radians': 0.12164759190152223, 'cos_theta': 0.9926100515613181, 'sin_theta': 0.12134778753416739}
# {'distance': array([ 3.94786942, -0.18811142, -0.34999999]), 'direction': array([ 1., -1., -1.]), 'xyz_offsets': [-3.9478694200515747, 0.18811142444610596, 0.3499999940395355], 'theta_degrees': 14.382873669922956, 'theta_radians': 0.2510285014385557, 'cos_theta': 0.9686574539624054, 'sin_theta': 0.24840035604457253}
# {'distance': array([3.36891222, 4.74757326, 0.        ]), 'direction': array([1., 1., 0.]), 'xyz_offsets': [-3.3689122200012207, -4.747573256492615, 0.0], 'theta_degrees': 26.9235388187326, 'theta_radians': 0.46990439867538863, 'cos_theta': 0.8916115806497489, 'sin_theta': 0.4528010482002624}
# {'distance': array([-2.92214835,  1.40173686,  0.34999999]), 'direction': array([-1.,  1.,  1.]), 'xyz_offsets': [2.92214834690094, -1.401736855506897, -0.3499999940395355], 'theta_degrees': 9.627779735978518, 'theta_radians': 0.16803645604961548, 'cos_theta': 0.985915063711307, 'sin_theta': 0.16724678516231478}
# {'distance': array([-4.48057151, -2.42648482,  0.34999999]), 'direction': array([-1., -1.,  1.]), 'xyz_offsets': [4.480571508407593, 2.4264848232269287, -0.3499999940395355], 'theta_degrees': 24.67323336441849, 'theta_radians': 0.43062915932202056, 'cos_theta': 0.9087032916376067, 'sin_theta': 0.41744260415891765}
# {'distance': array([-1.80461022, -2.9865967 ,  0.34999999]), 'direction': array([-1., -1.,  1.]), 'xyz_offsets': [1.8046102225780487, 2.986596703529358, -0.3499999940395355], 'theta_degrees': 19.40908025498115, 'theta_radians': 0.3387523552332416, 'cos_theta': 0.9431700050915995, 'sin_theta': 0.33231060996530354}
# {'distance': array([-0.53270209, -2.61459625,  0.        ]), 'direction': array([-1., -1.,  0.]), 'xyz_offsets': [0.5327020883560181, 2.6145962476730347, 0.0], 'theta_degrees': 13.503340610892874, 'theta_radians': 0.23567775367834312, 'cos_theta': 0.9723563077925709, 'sin_theta': 0.2335020571558186}
# {'distance': array([-1.11165929,  2.32108843,  0.34999999]), 'direction': array([-1.,  1.,  1.]), 'xyz_offsets': [1.111659288406372, -2.321088433265686, -0.3499999940395355], 'theta_degrees': 6.95088818933344, 'theta_radians': 0.12131588484185553, 'cos_theta': 0.9926502488701502, 'sin_theta': 0.12101852510268375}
# {'distance': array([-1.11753812,  4.38833356,  0.        ]), 'direction': array([-1.,  1.,  0.]), 'xyz_offsets': [1.1175381243228912, -4.388333559036255, 0.0], 'theta_degrees': 15.424942648462682, 'theta_radians': 0.26921603614696804, 'cos_theta': 0.9639797079828473, 'sin_theta': 0.2659757932543947}
# {'distance': array([-2.67596129,  0.56011188,  0.        ]), 'direction': array([-1.,  1.,  0.]), 'xyz_offsets': [2.675961285829544, -0.5601118803024292, 0.0], 'theta_degrees': 6.969893603887036, 'theta_radians': 0.12164759190152223, 'cos_theta': 0.9926100515613181, 'sin_theta': 0.12134778753416739}
# {'distance': array([ 1.80461022,  2.9865967 , -0.34999999]), 'direction': array([ 1.,  1., -1.]), 'xyz_offsets': [-1.8046102225780487, -2.986596703529358, 0.3499999940395355], 'theta_degrees': 19.40908025498115, 'theta_radians': 0.3387523552332416, 'cos_theta': 0.9431700050915995, 'sin_theta': 0.33231060996530354}
# {'distance': array([ 1.27190813,  0.37200046, -0.34999999]), 'direction': array([ 1.,  1., -1.]), 'xyz_offsets': [-1.2719081342220306, -0.37200045585632324, 0.3499999940395355], 'theta_degrees': 7.551927169052373, 'theta_radians': 0.13180599397077833, 'cos_theta': 0.9913261583163292, 'sin_theta': 0.13142468503971472}
# {'distance': array([0.69295093, 5.30768514, 0.        ]), 'direction': array([1., 1., 0.]), 'xyz_offsets': [-0.6929509341716766, -5.307685136795044, 0.0], 'theta_degrees': 23.10743799263675, 'theta_radians': 0.40330087467194053, 'cos_theta': 0.9197705573627694, 'sin_theta': 0.39245652218886695}
# {'distance': array([-2.38944626,  4.0163331 ,  0.34999999]), 'direction': array([-1.,  1.,  1.]), 'xyz_offsets': [2.389446258544922, -4.016333103179932, -0.3499999940395355], 'theta_degrees': 13.445251484359572, 'theta_radians': 0.2346639071607294, 'cos_theta': 0.972592543264445, 'sin_theta': 0.2325161172615754}
# {'distance': array([-3.94786942,  0.18811142,  0.34999999]), 'direction': array([-1.,  1.,  1.]), 'xyz_offsets': [3.9478694200515747, -0.18811142444610596, -0.3499999940395355], 'theta_degrees': 14.382873669922956, 'theta_radians': 0.2510285014385557, 'cos_theta': 0.9686574539624054, 'sin_theta': 0.24840035604457253}
# {'distance': array([0.53270209, 2.61459625, 0.        ]), 'direction': array([1., 1., 0.]), 'xyz_offsets': [-0.5327020883560181, -2.6145962476730347, 0.0], 'theta_degrees': 13.503340610892874, 'theta_radians': 0.23567775367834312, 'cos_theta': 0.9723563077925709, 'sin_theta': 0.2335020571558186}
# {'distance': array([-1.27190813, -0.37200046,  0.34999999]), 'direction': array([-1., -1.,  1.]), 'xyz_offsets': [1.2719081342220306, 0.37200045585632324, -0.3499999940395355], 'theta_degrees': 7.551927169052373, 'theta_radians': 0.13180599397077833, 'cos_theta': 0.9913261583163292, 'sin_theta': 0.13142468503971472}
# {'distance': array([-0.5789572 ,  4.93568468,  0.34999999]), 'direction': array([-1.,  1.,  1.]), 'xyz_offsets': [0.578957200050354, -4.935684680938721, -0.3499999940395355], 'theta_degrees': 18.803498387001902, 'theta_radians': 0.3281829577466261, 'cos_theta': 0.9466295813324923, 'sin_theta': 0.322323495492138}
# {'distance': array([-1.81048906, -0.91935158,  0.        ]), 'direction': array([-1., -1.,  0.]), 'xyz_offsets': [1.8104890584945679, 0.9193515777587891, 0.0], 'theta_degrees': 8.822803361020032, 'theta_radians': 0.1539869679058215, 'cos_theta': 0.9881674157772941, 'sin_theta': 0.15337913285719298}
# {'distance': array([-3.36891222, -4.74757326,  0.        ]), 'direction': array([-1., -1.,  0.]), 'xyz_offsets': [3.3689122200012207, 4.747573256492615, 0.0], 'theta_degrees': 26.9235388187326, 'theta_radians': 0.46990439867538863, 'cos_theta': 0.8916115806497489, 'sin_theta': 0.4528010482002624}
# {'distance': array([ 1.11165929, -2.32108843, -0.34999999]), 'direction': array([ 1., -1., -1.]), 'xyz_offsets': [-1.111659288406372, 2.321088433265686, 0.3499999940395355], 'theta_degrees': 6.95088818933344, 'theta_radians': 0.12131588484185553, 'cos_theta': 0.9926502488701502, 'sin_theta': 0.12101852510268375}
# {'distance': array([-0.69295093, -5.30768514,  0.        ]), 'direction': array([-1., -1.,  0.]), 'xyz_offsets': [0.6929509341716766, 5.307685136795044, 0.0], 'theta_degrees': 23.10743799263675, 'theta_radians': 0.40330087467194053, 'cos_theta': 0.9197705573627694, 'sin_theta': 0.39245652218886695}
# {'distance': array([ 0.5789572 , -4.93568468, -0.34999999]), 'direction': array([ 1., -1., -1.]), 'xyz_offsets': [-0.578957200050354, 4.935684680938721, 0.3499999940395355], 'theta_degrees': 18.803498387001902, 'theta_radians': 0.3281829577466261, 'cos_theta': 0.9466295813324923, 'sin_theta': 0.322323495492138}
# Max X Offset: 4.480571508407593
# Min X Offset: 0.5327020883560181
# Max Y Offset: 5.307685136795044
# Min Y Offset: 0.18811142444610596
# Max Degrees: 26.9235388187326
# Min Degrees: 6.95088818933344
# Max Radians: 0.46990439867538863
# Min Radians: 0.12131588484185553
# Max Cos(Theta): 0.9926502488701502
# Min Cos(Theta): 0.8916115806497489
# Max Sin(Theta): 0.4528010482002624
# Min Sin(Theta): 0.12101852510268375
# Max X Offset: 4.480571508407593
# Min X Offset: 0.5327020883560181
# Max Y Offset: 5.307685136795044
# Min Y Offset: 0.18811142444610596
# Max Degrees: 26.9235388187326
# Min Degrees: 6.95088818933344
# Max Radians: 0.46990439867538863
# Min Radians: 0.12131588484185553
# Max Cos(Theta): 0.9926502488701502
# Min Cos(Theta): 0.8916115806497489
# Max Sin(Theta): 0.4528010482002624
# Min Sin(Theta): 0.12101852510268375

# %%
scene_info.show_combined_graph()
